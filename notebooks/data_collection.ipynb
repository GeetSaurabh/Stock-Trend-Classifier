# %%
import yfinance as yf

# Example: Get Apple stock data for last 1 year
ticker = 'AAPL'
data = yf.download(ticker, start='2023-06-01', end='2024-06-01')
print(data.head())
# Out:
# /tmp/ipykernel_23608/1102589154.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start='2023-06-01', end='2024-06-01')
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-06-01  178.304749  178.334450  175.176070  175.938441   68901800
# 2023-06-02  179.156235  179.978009  177.482985  179.235444   61945900
# 2023-06-05  177.799850  183.116614  176.275108  180.819619  121946500
# 2023-06-06  177.433472  178.334439  175.671103  178.185932   64848400
# 2023-06-07  176.057266  179.413660  175.562223  176.671115   61944600
